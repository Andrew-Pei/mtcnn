# %%
import os
import glob
import cv2
import pandas as pd
from tqdm import tqdm

#os.chdir("../../../data1/pbw_deepfake/train/dfdc_train_part_0/dfdc_train_part_0/")

# %%
fake_list=['5','10','15','20','25','30','35','40','45','50','90','91','92','93','94','95','96','97','98','99']

real_list=[]
for i in range(5,251,5):
    real_list.append(str(i))
for i in range(50,100):
    real_list.append(str(i))

for i in range(50):
    os.chdir("../../dfdc_train_part_%d/dfdc_train_part_%d/" % (i, i))
    for file in tqdm(glob.glob("./*/*.jpg")):
        metadata = pd.read_json("./metadata.json")
        #print(file.split("/")[-2][:-4]+".mp4")
        if metadata.iloc[0][file.split("/")[-2][:-4]+".mp4"] == "FAKE":
            if file.split("/")[-1][:-4] not in fake_list:
                #print(file)
                os.remove(file)
        else:
            if file.split("/")[-1][:-4] not in real_list:
                #print(file)
                os.remove(file)
# Out:
#   2%|▏         | 9566/400064 [59:35<40:32:16,  2.68it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-f5c597e08be1> in <module>
#      10     os.chdir("../../dfdc_train_part_%d/dfdc_train_part_%d/" % (i, i))
#      11     for file in tqdm(glob.glob("./*/*.jpg")):
# ---> 12         metadata = pd.read_json("./metadata.json")
#      13         #print(file.split("/")[-2][:-4]+".mp4")
#      14         if metadata.iloc[0][file.split("/")[-2][:-4]+".mp4"] == "FAKE":
#
# ~/miniconda3/envs/mtcnn/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ...
